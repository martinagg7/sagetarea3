# %%
x = var('x')
solve(x**3 -x == 7*(x**2)-7,x)
# Out:
# [x == 7, x == -1, x == 1]

# %%
t=var('t')
solve(abs(t-7)>=3,t)
# Out:
# #0: solve_rat_ineq(ineq=abs(_SAGE_VAR_t-7) >= 3)
# [[t == 10], [t == 4], [t < 4], [10 < t]]

# %%
x,y=var('x,y')
solve([2*x+y==17,x-3*y==-16],x,y)
# Out:
# [[x == 5, y == 7]]

# %%
#me dice que el size limit es demasido pequeño,no soy capaz de solucionar el problema pero la he resuelto graficamente
x=var('x')
f=exp(x)==cos(x)
find_root(f, (-pi/2), 0)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/martinagarciagonzalez/sagetarea3-2/sage.ipynb Celda 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/martinagarciagonzalez/sagetarea3-2/sage.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> x=var('x')
#       <a href='vscode-notebook-cell:/Users/martinagarciagonzalez/sagetarea3-2/sage.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> f=exp(x)==cos(x)
# ----> <a href='vscode-notebook-cell:/Users/martinagarciagonzalez/sagetarea3-2/sage.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> find_root(f, (-pi/Integer(2)), Integer(0))
#
# File /private/var/tmp/sage-9.7-current/local/var/lib/sage/venv-python3.10.5/lib/python3.10/site-packages/sage/misc/lazy_import.pyx:391, in sage.misc.lazy_import.LazyImport.__call__ (build/cythonized/sage/misc/lazy_import.c:4397)()
#     389         True
#     390     """
# ...

# %%
f(x)=exp(x)-cos(x)
plot(f(x),(-pi/2,0))
# Out:
# Graphics object consisting of 1 graphics primitive
